# %% [markdown]
# # Example of wine quality test

# %%
import pandas as pd
import numpy as np

# %%
D1= pd.read_csv("E:/Neha Python/wineQualityReds.csv")
D1.head()
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0           1            7.4              0.70         0.00             1.9
# 1           2            7.8              0.88         0.00             2.6
# 2           3            7.8              0.76         0.04             2.3
# 3           4           11.2              0.28         0.56             1.9
# 4           5            7.4              0.70         0.00             1.9
#
#    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# ...

# %%
array=D1.values
X=array[:,1:12]
y=array[:,12]

# %%
X
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  3.57 ,  0.71 , 10.2  ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
y
# Out:
# array([5., 5., 5., ..., 6., 5., 6.])

# %%
#Try to select features from 11 'x' fields from sklearn.linear_model import LogisticRegression

# %%
# The above method is manual as we define precision=3
# Now above proceure can be done manually by using OLS as follows:

from sklearn.feature_selection import RFE  #(RFE- Recursive Forward Elemination)
from sklearn.linear_model import LogisticRegression
# OLs model is best as it utomatically gives bests fields based on p values

# %%
X1=sm.add_constant(X)  # X is Defined above which is fields except outcomes 

X1
# Out:
# array([[ 1.   ,  7.4  ,  0.7  , ...,  3.51 ,  0.56 ,  9.4  ],
#        [ 1.   ,  7.8  ,  0.88 , ...,  3.2  ,  0.68 ,  9.8  ],
#        [ 1.   ,  7.8  ,  0.76 , ...,  3.26 ,  0.65 ,  9.8  ],
#        ...,
#        [ 1.   ,  6.3  ,  0.51 , ...,  3.42 ,  0.75 , 11.   ],
#        [ 1.   ,  5.9  ,  0.645, ...,  3.57 ,  0.71 , 10.2  ],
#        [ 1.   ,  6.   ,  0.31 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
model=sm.OLS(y,X1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.361
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     81.35
# Date:                Wed, 11 Sep 2019   Prob (F-statistic):          1.79e-145
# Time:                        18:24:13   Log-Likelihood:                -1569.1
# No. Observations:                1599   AIC:                             3162.
# Df Residuals:                    1587   BIC:                             3227.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         21.9652     21.195      1.036      0.300     -19.607      63.538
# ...

# %%
# If we apply classifiers on whole 11 fields wihtout feature selection by OLS then accuracy is 68% as shown in below code :summary()

# %%
from sklearn.model_selection import train_test_split
(X_train, X_test, y_train, y_test) =train_test_split(X,y,test_size=0.25,random_state=0) # random state=0 means it starts from index 0

# %%
classifier=LogisticRegression(random_state=0)

# %%
classifier.fit(X_train,y_train)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=classifier.predict(X_test)

# %%
y_pred
# Out:
# array([6., 5., 6., 5., 6., 5., 5., 6., 5., 5., 5., 5., 6., 5., 6., 6., 7.,
#        6., 6., 5., 6., 5., 6., 5., 5., 5., 5., 6., 5., 6., 6., 6., 6., 5.,
#        6., 6., 5., 5., 6., 6., 5., 6., 7., 6., 6., 5., 6., 6., 5., 6., 5.,
#        5., 6., 6., 5., 5., 5., 5., 6., 5., 5., 6., 6., 6., 5., 6., 5., 6.,
#        6., 6., 5., 5., 5., 5., 5., 6., 5., 5., 5., 6., 5., 5., 6., 6., 6.,
#        5., 6., 5., 5., 5., 5., 5., 6., 5., 6., 5., 6., 5., 5., 6., 7., 6.,
#        6., 6., 5., 5., 5., 5., 6., 5., 6., 5., 6., 5., 6., 6., 6., 6., 6.,
#        6., 5., 6., 6., 5., 6., 6., 5., 5., 6., 6., 5., 5., 6., 6., 6., 5.,
#        6., 5., 6., 5., 6., 5., 6., 5., 6., 6., 6., 6., 6., 5., 6., 6., 5.,
#        6., 6., 6., 5., 5., 6., 6., 6., 6., 6., 5., 6., 5., 6., 6., 5., 6.,
#        6., 5., 5., 7., 6., 6., 7., 7., 6., 5., 5., 7., 5., 6., 7., 5., 6.,
#        6., 5., 6., 6., 6., 5., 5., 5., 5., 5., 5., 5., 5., 5., 6., 5., 5.,
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6225

# %%
# Now lets apply selected featured fields and apply classifiers and lets see result


X2=D1[['volatile.acidity','chlorides','free.sulfur.dioxide','total.sulfur.dioxide','pH','sulphates','alcohol']]

# %%
X2
# Out:
#       volatile.acidity  chlorides  free.sulfur.dioxide  total.sulfur.dioxide  \
# 0                0.700      0.076                 11.0                  34.0
# 1                0.880      0.098                 25.0                  67.0
# 2                0.760      0.092                 15.0                  54.0
# 3                0.280      0.075                 17.0                  60.0
# 4                0.700      0.076                 11.0                  34.0
# 5                0.660      0.075                 13.0                  40.0
# 6                0.600      0.069                 15.0                  59.0
# 7                0.650      0.065                 15.0                  21.0
# 8                0.580      0.073                  9.0                  18.0
# 9                0.500      0.071                 17.0                 102.0
# 10               0.580      0.097                 15.0                  65.0
# ...

# %%
from sklearn.model_selection import train_test_split
(X_train, X_test, y_train, y_test) =train_test_split(X2,y,test_size=0.25,random_state=0) # random state=0 means it starts from index 0

# %%
## To increse the accuracy add std. scalar steps. Step to increase the accuracy are as follows
#Step 1:
from sklearn.preprocessing import StandardScaler

# %%
#Step 2:
sc=StandardScaler()

# %%
#Step 3:
x_train=sc.fit_transform(X_train)

# %%
#Step 4:
x_test=sc.transform(X_test)

# %%
classifier=LogisticRegression(random_state=0)

# %%
classifier.fit(x_train,y_train)
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Asus\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=classifier.predict(x_test)

# %%
y_pred
# Out:
# array([6., 5., 6., 5., 6., 5., 5., 6., 5., 5., 5., 5., 6., 5., 6., 6., 7.,
#        6., 6., 5., 6., 5., 6., 5., 5., 5., 5., 6., 5., 6., 6., 6., 6., 5.,
#        6., 6., 5., 5., 6., 6., 5., 6., 7., 6., 6., 5., 5., 6., 5., 6., 5.,
#        5., 6., 6., 6., 5., 5., 5., 6., 5., 5., 6., 6., 6., 5., 6., 5., 6.,
#        6., 6., 5., 5., 5., 5., 5., 6., 5., 5., 5., 6., 5., 5., 6., 6., 5.,
#        5., 6., 5., 5., 5., 5., 5., 6., 5., 6., 5., 6., 5., 5., 6., 7., 6.,
#        6., 6., 6., 5., 6., 5., 6., 5., 6., 5., 6., 5., 6., 6., 6., 6., 6.,
#        6., 5., 6., 5., 5., 6., 6., 5., 5., 6., 6., 5., 5., 6., 6., 6., 5.,
#        6., 5., 6., 5., 6., 5., 5., 5., 6., 6., 6., 6., 6., 5., 6., 6., 5.,
#        5., 6., 5., 5., 5., 6., 6., 6., 5., 6., 5., 6., 5., 6., 6., 5., 6.,
#        6., 5., 5., 7., 6., 6., 6., 7., 6., 5., 5., 7., 5., 6., 7., 5., 6.,
#        6., 5., 6., 6., 6., 5., 5., 5., 5., 5., 5., 5., 5., 5., 6., 5., 5.,
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6125

# %%
#By applying 4 tests still we are not getting accuracy so to check how much difference is there in predictions by following function
classifier.predict([[0.280,0.092,35.0,103.0,3.30,0.75,10.5]])
# Out:
# array([5.])
